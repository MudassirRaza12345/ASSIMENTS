# %%
#Main Menu
#Add Tasks
#view Tasks
#Delete Tasks
#Terminate APP

def isInteger(userInput):
    try:
        int(userInput)
        return True
    except ValueError:
        return False

def mainMenu(menu):
    print("-------------------\n     Main Menu    \n--------------------\n")
    for menukey,menuName in menu.items():
        print("{}.{}".format(menukey,menuName))
    
    usercommand = input("Enter Command :")
    print(usercommand)
    return usercommand

def addTask(taskDictionary):
    print("-------------------\n     Adding Task     \n--------------------\n")
    taskIndex = len(taskDictionary) + 1
    taskName = input("Task #{}".format(taskIndex))
    taskDictionary.update({taskIndex : taskName})
    print("Task #{} - Successfully Added\n".format(taskIndex))
def viewTask(taskDictionary):
    print("-------------------\n     View Task     \n--------------------\n")
    if len(taskDictionary) > 0:
        for taskIndex,taskName in taskDictionary.items():
            print("Task #{} - {}".format(taskIndex,taskName))
            
    else:
        print("No Task Found\n")
def deleteTask(taskDictionary):
    print("-------------------\n     Delete Task     \n--------------------\n")
    if len(taskDictionary) > 0:
        for taskIndex,taskName in taskDictionary.items():
            print("Task #{} - {}".format(taskIndex,taskName))
        taskIndex = int(input("Enter Task Index e.g 1:"))
        if taskIndex in taskDictionary.keys():
            taskDictionary.pop(taskIndex)
            print("Task #{} - Sucessfully Deleted".format(taskIndex))
        else:
            print("Invalid Command , Try valid command")
    else:
        print("No Task Found\n")
menu = {
    1 : "Add Tasks",
    2 : "View Tasks",
    3 : "Delete Tasks",
    4 : "Terminate App",
}
taskDictionary = {}
while (True):
    usercommand = mainMenu(menu)
    if isInteger(usercommand) == True:
        usercommand = int(usercommand)
        if usercommand > 0 and usercommand <= 4:
                                          
            #Add Tasks
            if usercommand == 1:
                addTask(taskDictionary)
            if usercommand == 2:
                viewTask(taskDictionary)
            if usercommand == 3:
                deleteTask(taskDictionary)
            if usercommand == 4:
                print("App Terminated ")
                break
                        
        else:
            print("Invalid Command , Try valid command")
    else:
        print("Invalid Command , Try valid command")
# Out:
# -------------------
#      Main Menu
# --------------------
#
# 1.Add Tasks
# 2.View Tasks
# 3.Delete Tasks
# 4.Terminate App
# Enter Command :1
# 1
# -------------------
#      Adding Task
# --------------------
#
# Task #1Lunch
# Task #1 - Successfully Added
#
# -------------------
#      Main Menu
# --------------------
#
# 1.Add Tasks
# 2.View Tasks
# 3.Delete Tasks
# 4.Terminate App
# Enter Command :1
# 1
# -------------------
#      Adding Task
# --------------------
#
# Task #2Dinner
# Task #2 - Successfully Added
#
# -------------------
#      Main Menu
# --------------------
#
# 1.Add Tasks
# 2.View Tasks
# 3.Delete Tasks
# 4.Terminate App
# Enter Command :1
# 1
# -------------------
#      Adding Task
# --------------------
#
# Task #3Brunch
# Task #3 - Successfully Added
#
# -------------------
#      Main Menu
# --------------------
#
# 1.Add Tasks
# 2.View Tasks
# 3.Delete Tasks
# 4.Terminate App
# Enter Command :2
# 2
# -------------------
#      View Task
# --------------------
#
# Task #1 - Lunch
# Task #2 - Dinner
# Task #3 - Brunch
# -------------------
#      Main Menu
# --------------------
#
# 1.Add Tasks
# 2.View Tasks
# 3.Delete Tasks
# 4.Terminate App
# Enter Command :3
# 3
# -------------------
#      Delete Task
# --------------------
#
# Task #1 - Lunch
# Task #2 - Dinner
# Task #3 - Brunch
# Enter Task Index e.g 1:1
# Task #1 - Sucessfully Deleted
# -------------------
#      Main Menu
# --------------------
#
# 1.Add Tasks
# 2.View Tasks
# 3.Delete Tasks
# 4.Terminate App
# Enter Command :2
# 2
# -------------------
#      View Task
# --------------------
#
# Task #2 - Dinner
# Task #3 - Brunch
# -------------------
#      Main Menu
# --------------------
#
# 1.Add Tasks
# 2.View Tasks
# 3.Delete Tasks
# 4.Terminate App
# Enter Command :2
# 2
# -------------------
#      View Task
# --------------------
#
# Task #2 - Dinner
# Task #3 - Brunch
# -------------------
#      Main Menu
# --------------------
#
# 1.Add Tasks
# 2.View Tasks
# 3.Delete Tasks
# 4.Terminate App
# Enter Command :4
# 4
# App Terminated
